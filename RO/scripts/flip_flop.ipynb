# %% [markdown]
# # Flip Flop Problem

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sqlite3 as sql
from util import *

def generate_sql_z_query(z_name: str, filters: dict):
	where_close = ""
	first_key = True
	for k, lf in filters.items():
		if first_key:
			first_key = False
		else:
			where_close += "AND "
		where_close += "("
		first = True
		for v in lf:
			if not first:
				where_close += " OR "
			else:
				first = False
			where_close += str(k)+"='"+str(v)+"'"
		where_close += ") "
	return "SELECT DISTINCT "+z_name+" FROM problems WHERE "+where_close

def generate_sql_xy_query(x_name: str, y_name: str, z_name: str, z_value, filters: dict, x_limit):
	where_close = z_name+" = '"+str(z_value)+"' "
	for k, lf in filters.items():
		where_close += "AND ("
		first = True
		for v in lf:
			if not first:
				where_close += " OR "
			else:
				first = False
			where_close += str(k)+"='"+str(v)+"'"
		where_close += ") "
	if x_limit > 0:
		where_close += "AND "+x_name+" < "+str(x_limit)+" "
	return ("SELECT "+x_name+","
			"min("+y_name+") as min,"
			"max("+y_name+") as max,"
			"median("+y_name+") as median,"
			"avg("+y_name+") as mean "
			"FROM problems "
			"WHERE "+where_close+""
			"GROUP BY "+x_name)

def consolidate_data_from_db(con, x_name: str, y_name: str, z_name: str, filters: dict, x_limit=-1):
	z_value_df = pd.read_sql_query(generate_sql_z_query(z_name, filters), con)
	cd = dict()
	for i in z_value_df.get(z_name):
		query = generate_sql_xy_query(x_name, y_name, z_name, i, filters, x_limit)
		print("Selecting data for", z_name, "=", i)
		#print(query)
		cd[i] = pd.read_sql_query(query, con)
	return cd

def generate_plot(con, x_arg_name, y_arg_name, z_arg_name, filters, save_to_file=True, x_limit=-1, x_name=None, y_name=None):
	if x_name is None:
		x_name = x_arg_name
	if y_name is None:
		y_name = y_arg_name
		
	cd = consolidate_data_from_db(con, x_arg_name, y_arg_name, z_arg_name, filters, x_limit)
	
	plt.figure()
	for a, d in cd.items():
		plt.plot(d.get(x_arg_name),d.get('median'), 
				 label=z_arg_name.replace('_',' ') + ' = ' + str(a).replace('_',' '))
		#plt.fill_between(d.get(x_arg_name), d.get('mean') - d.get('std'), d.get('mean') + d.get('std'), alpha=0.3)
		plt.fill_between(d.get(x_arg_name), d.get('min'), d.get('max'), alpha=0.3)
	if y_arg_name == "Error":
		plt.ylabel("Accuracy")
	else:
		plt.ylabel(y_name.replace('_',' '))
	plt.xlabel(x_name.replace('_',' '))
	plt.legend()
	if save_to_file:
		problem_name = ""
		if "Problem" in filters.keys():
			for pb in filters["Problem"]:
				problem_name += str(pb) + "_"
		algo_name = "all_"
		if "Algorithm" in filters.keys():
			algo_name = '_'.join(map(str, filters["Algorithm"])) + '_'
		plt.savefig("../graphics/"+problem_name+algo_name+x_name+"_"+y_name+"_"+z_arg_name+".png")
	plt.show()

sns.set()
con = sql.connect("./problems.db")
# con.execute(('CREATE TABLE IF NOT EXISTS "problems" ('
# 	'"Problem" TEXT,'
# 	'"Algorithm" TEXT,'
# 	'"N" INTEGER,'
# 	'"T" INTEGER,'
# 	'"SA_initial_temperature" REAL,'
# 	'"SA_cooling_factor" REAL,'
# 	'"GA_population" REAL,'
# 	'"GA_mate_number" REAL,'
# 	'"GA_mutate_number" REAL,'
# 	'"MIMIC_samples" REAL,'
# 	'"MIMIC_to_keep" REAL,'
# 	'"Error" REAL,'
# 	'"Time" REAL,'
# 	'"Iteration" INTEGER'
# ');'))
# con.execute('CREATE INDEX "PB" on "problems" ("Problem");')
# con.execute('CREATE INDEX "ALG" on "problems" ("Algorithm");')
con.enable_load_extension(True)
con.load_extension("./extension-functions")
# df = pd.read_csv(
# 	"../stats/problems_results.csv",
# 	names=(
# 		"Problem", 
# 		"Algorithm", 
# 		"N",
# 		"T",
# 		"SA_initial_temperature",
# 		"SA_cooling_factor",
# 		"GA_population",
# 		"GA_mate_number",
# 		"GA_mutate_number",
# 		"MIMIC_samples",
# 		"MIMIC_to_keep",
# 		"Error",
# 		"Time",
# 		"Iteration"
# 	)
# )
# df.to_sql("problems", con, if_exists='append', index=False)

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'Algorithm',
	filters = {"Problem": ["flip_flop"]},
	x_limit=5000
)
# Out:
# Selecting data for Algorithm = RHC
# Selecting data for Algorithm = SA
# Selecting data for Algorithm = GA
# Selecting data for Algorithm = MIMIC

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Time',
	z_arg_name = 'Algorithm',
	filters = {"Problem": ["flip_flop"]},
	x_limit=5000
)
# Out:
# Selecting data for Algorithm = RHC
# Selecting data for Algorithm = SA
# Selecting data for Algorithm = GA
# Selecting data for Algorithm = MIMIC

# %%
print(pd.read_sql_query("SELECT Algorithm, max(Time)/10e9 from problems WHERE Problem = 'flip_flop' GROUP BY Algorithm", con))
# Out:
#   Algorithm  max(Time)/10e9
# 0        GA        2.434540
# 1     MIMIC       20.987420
# 2       RHC        0.002077
# 3        SA        0.007648

# %%
print(pd.read_sql_query("SELECT Algorithm, avg(Time/Iteration) from problems WHERE Problem = 'flip_flop' GROUP BY Algorithm", con))
# Out:
#   Algorithm  avg(Time/Iteration)
# 0        GA         2.546197e+06
# 1     MIMIC         2.730148e+07
# 2       RHC         2.957007e+03
# 3        SA         5.819164e+03

# %% [markdown]
# ## Simulated Annealing

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'SA_initial_temperature',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['SA']},
	x_limit=5000
)
# Out:
# Selecting data for SA_initial_temperature = 50.0
# Selecting data for SA_initial_temperature = 100.0
# Selecting data for SA_initial_temperature = 150.0
# Selecting data for SA_initial_temperature = 200.0

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'SA_cooling_factor',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['SA']},
	x_limit=5000
)
# Out:
# Selecting data for SA_cooling_factor = 0.5
# Selecting data for SA_cooling_factor = 0.55
# Selecting data for SA_cooling_factor = 0.6000000000000001
# Selecting data for SA_cooling_factor = 0.6500000000000001
# Selecting data for SA_cooling_factor = 0.7000000000000002
# Selecting data for SA_cooling_factor = 0.7500000000000002
# Selecting data for SA_cooling_factor = 0.8000000000000003
# Selecting data for SA_cooling_factor = 0.8500000000000003
# Selecting data for SA_cooling_factor = 0.9000000000000004
# Selecting data for SA_cooling_factor = 0.9500000000000004

# %% [markdown]
# ## Genetic Algorithm

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'GA_population',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['GA']},
	x_limit=5000
)
# Out:
# Selecting data for GA_population = 100.0
# Selecting data for GA_population = 200.0
# Selecting data for GA_population = 300.0
# Selecting data for GA_population = 400.0
# Selecting data for GA_population = 500.0
# Selecting data for GA_population = 600.0

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'GA_mate_number',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['GA'], 'GA_population': [600]},
	x_limit=5000
)
# Out:
# Selecting data for GA_mate_number = 50.0
# Selecting data for GA_mate_number = 150.0
# Selecting data for GA_mate_number = 250.0
# Selecting data for GA_mate_number = 350.0
# Selecting data for GA_mate_number = 450.0
# Selecting data for GA_mate_number = 550.0

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'GA_mutate_number',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['GA'], 'GA_population': [600]},
	x_limit=5000
)
# Out:
# Selecting data for GA_mutate_number = 10.0
# Selecting data for GA_mutate_number = 30.0
# Selecting data for GA_mutate_number = 50.0
# Selecting data for GA_mutate_number = 70.0
# Selecting data for GA_mutate_number = 90.0
# Selecting data for GA_mutate_number = 110.0

# %% [markdown]
# ## MIMIC

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'MIMIC_to_keep',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['MIMIC']},
	x_limit=5000
)
# Out:
# Selecting data for MIMIC_to_keep = 10.0
# Selecting data for MIMIC_to_keep = 60.0
# Selecting data for MIMIC_to_keep = 110.0
# Selecting data for MIMIC_to_keep = 160.0

# %%
generate_plot(
	con=con,
	x_arg_name = 'Iteration',
	y_arg_name = 'Error',
	z_arg_name = 'MIMIC_samples',
	filters = {"Problem": ["flip_flop"], 'Algorithm': ['MIMIC']},
	x_limit=5000
)
# Out:
# Selecting data for MIMIC_samples = 50.0
# Selecting data for MIMIC_samples = 150.0
# Selecting data for MIMIC_samples = 250.0
# Selecting data for MIMIC_samples = 350.0
